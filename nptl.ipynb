# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from time import sleep
import time

# chrome_options = webdriver.ChromeOptions()
# chrome_options.add_argument('--no-sandbox')
# chrome_options.add_argument('--window-size=820,680')
# chrome_options.add_argument('--headless')
# chrome_options.add_argument('--disable-gpu')
# driver = webdriver.Chrome(chrome_options=chrome_options)

username = "-----------"
password = "-----------------"

driver = webdriver.Chrome()  #//*[@id="identifierNext"]
driver.get("https://accounts.google.com/ServiceLogin?service=ah&passive=true&continue=https://appengine.google.com/_ah/conflogin%3Fcontinue%3Dhttps://onl-------------/")
emailelement = driver.find_element(By.XPATH, './/*[@id="identifierId"]')
emailelement.send_keys(username)
nextbtn = driver.find_element(By.XPATH, './/*[@id="identifierNext"]')
nextbtn.click()
time.sleep(5)  #//*[@id="password"]/div[1]/div/div[1]/input
paselement = driver.find_element(By.XPATH, '//*[@id="password"]/div[1]/div/div[1]/input')
time.sleep(10)
paselement.send_keys(password)

loginelement = driver.find_element(By.XPATH, './/*[@id="passwordNext"]')
loginelement.click()
time.sleep(10)

driver.get("https://onlinecours----------------n/noc19_ge11/unit?unit=25&assessment=92")
html = driver.page_source
time.sleep(4)
driver.quit()

# %%
from bs4 import BeautifulSoup as bs
soup = bs(html, 'html.parser')
a = soup.findAll(class_= 'qt-question')
c= ''
count = 1
for b in a:
    print("\n"+f'{count}) '+ b.get_text().replace('\n', ' ') + '.' + '\na) True\nb) False\n\nAnswer: ')
    count += 1 
# c
# Out:
# 1) The solar spectrum ranges from Violet to Red..
# a) True
# b) False
#
# Answer:
#
# 2) A blackbody absorbs radiation incident on it..
# a) True
# b) False
#
# Answer:
#
# 3) As the temperature of a body increases, the intensity of the radiation coming from the body increases.
# a) True
# b) False
#
# Answer:
#
# 4) As the temperature of a body increases, the wavelength at which the maximum intensity occurs, increases.
# a) True
# b) False
#
# Answer:
#
# 5) Humans and animals give out Infrared radiation.
# a) True
# b) False
#
# Answer:
#
# 6) A flat plate collector typically does not need to track the sun across seasons since it is flat.
# a) True
# b) False
#
# Answer:
#
# 7) A glass plate is used on top of the flat plate collector in order to prevent IR radiation from coming in..
# a) True
# b) False
#
# Answer:
#
# 8) In order to heat air it is important to increase the area of contact between the air and the surface gathering the heat..
# a) True
# b) False
#
# Answer:
#
# ...
